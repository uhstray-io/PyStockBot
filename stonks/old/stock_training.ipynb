# %%
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")

# %%
stock = "AAPL"

# %%
end = datetime.now()
start = datetime(end.year - 10, end.month, end.day)

# %%
df = yf.download(stock, start, end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-07-21   23.747499   23.750000   23.430000   23.485001   20.773312
# 2014-07-22   23.670000   23.722500   23.530001   23.680000   20.945791
# 2014-07-23   23.855000   24.469999   23.792500   24.297501   21.491993
# 2014-07-24   24.260000   24.330000   24.105000   24.257500   21.456608
# 2014-07-25   24.212500   24.459999   24.160000   24.417500   21.598141
# ...                ...         ...         ...         ...         ...
# 2024-07-12  228.919998  232.639999  228.679993  230.539993  230.539993
# 2024-07-15  236.479996  237.229996  233.089996  234.399994  234.399994
# 2024-07-16  235.000000  236.270004  232.330002  234.820007  234.820007
# 2024-07-17  229.449997  231.460007  226.639999  228.880005  228.880005
# 2024-07-18  230.279999  230.440002  222.270004  224.179993  224.179993
#
#                Volume
# Date
# 2014-07-21  156316000
# 2014-07-22  220788000
# 2014-07-23  371672000
# 2014-07-24  182916000
# 2014-07-25  173876000
# ...               ...
# 2024-07-12   53008200
# 2024-07-15   62631300
# 2024-07-16   43234300
# 2024-07-17   57345900
# 2024-07-18   66034600
#
# [2516 rows x 6 columns]

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(x="Date", y="Close", data=df)
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
data = df.filter(['Close'])
data
# Out:
#                  Close
# Date
# 2014-07-21   23.485001
# 2014-07-22   23.680000
# 2014-07-23   24.297501
# 2014-07-24   24.257500
# 2014-07-25   24.417500
# ...                ...
# 2024-07-12  230.539993
# 2024-07-15  234.399994
# 2024-07-16  234.820007
# 2024-07-17  228.880005
# 2024-07-18  224.179993
#
# [2516 rows x 1 columns]

# %%
# # replace Close with the count of days
# data["Close"] = range(1, len(data) + 1)
# data

# %%
dataset = data.values
dataset
# Out:
# array([[ 23.48500061],
#        [ 23.68000031],
#        [ 24.29750061],
#        ...,
#        [234.82000732],
#        [228.88000488],
#        [224.17999268]])

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

scaled_data, max(scaled_data), min(scaled_data)
# Out:
# (array([[0.00424059],
#         [0.00515938],
#         [0.00806889],
#         ...,
#         [1.        ],
#         [0.97201215],
#         [0.94986683]]),
#  array([1.]),
#  array([0.]))

# %%
# train_data = scaled_data[0:int(training_data_len), :]
# test_data = scaled_data[training_data_len - 60:, :]

# train_data

# %%
# len(train_data), len(test_data)

# %%
# How many days to look back
from sklearn.model_selection import train_test_split
days = 60

x = []
y = []

# Create two arrays, x_train and y_train
# x_train contain arrays of 60 days of data
# y_train contain the 61st day data
for i in range(days, len(scaled_data)):
    x.append(scaled_data[i-days:i, 0])
    y.append(scaled_data[i, 0])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.05, random_state=42, shuffle=False)


# x_train
# y_train
# x_train[-1], y_train[-2]

# %%
x_test[1], y_test[0]
# Out:
# (array([0.67993024, 0.68619689, 0.69595019, 0.69821189, 0.7132895 ,
#         0.73025185, 0.72591697, 0.73807332, 0.75027683, 0.75531837,
#         0.75305675, 0.77185661, 0.76431784, 0.77675688, 0.77944255,
#         0.78745259, 0.78735834, 0.79565101, 0.79183449, 0.79499136,
#         0.78867762, 0.78782947, 0.79070365, 0.78585054, 0.78858337,
#         0.79466158, 0.78613323, 0.80493318, 0.79975028, 0.8089382 ,
#         0.81572314, 0.80380233, 0.81101138, 0.8263246 , 0.82703133,
#         0.82448701, 0.81657122, 0.82151858, 0.81157677, 0.81086996,
#         0.80578133, 0.80318985, 0.80366098, 0.80568707, 0.80073971,
#         0.7682757 , 0.76172636, 0.75070087, 0.74726123, 0.76789875,
#         0.76591982, 0.77086718, 0.7680401 , 0.76959499, 0.7588051 ,
#         0.75432887, 0.78236389, 0.7961693 , 0.80714771, 0.81322584]),
#  0.8132258434779096)

# %%
x_test[-1], y_test[-1]
# Out:
# (array([0.67498288, 0.67997733, 0.68996631, 0.69406552, 0.6912856 ,
#         0.71107496, 0.6961387 , 0.6912856 , 0.70886043, 0.75762716,
#         0.74975853, 0.75300958, 0.75461163, 0.76323416, 0.75607227,
#         0.77129123, 0.77670972, 0.78749969, 0.78806507, 0.78820642,
#         0.79371917, 0.79989163, 0.79305952, 0.77411831, 0.78872472,
#         0.78877188, 0.79018535, 0.79489711, 0.79942043, 0.80780735,
#         0.80931515, 0.81647697, 0.80992763, 0.82128298, 0.80351963,
#         0.86962559, 0.89751926, 0.90303201, 0.89478644, 0.91448155,
#         0.90326754, 0.88154633, 0.87122764, 0.87429026, 0.87867223,
#         0.89836735, 0.90237237, 0.8859754 , 0.9148585 , 0.93144391,
#         0.93747495, 0.96004424, 0.96701769, 0.97106974, 0.99133031,
#         0.96583975, 0.97983361, 0.998021  , 1.        , 0.97201215]),
#  0.9498668257575196)

# %%
x_test = np.array(x_test)
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
# LSTM expects the input to be 3D
# x_train.shape[0] is the number of samples
# x_train.shape[1] is the number of time steps
# 1 is the number of features

# The reason we need to reshape the data is because LSTM expects the input to be 3D
# In this case, 2332, 60, 1
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# x_train

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# Epoch 1/2
# c:\Users\jacob\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2333/2333 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - loss: 0.0023
# Epoch 2/2
# 2333/2333 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - loss: 6.5006e-04

# %%
# x_test

# %%
x_test_last60 = x_test[-1].flatten()
x_test_last60
# Out:
# array([0.67498288, 0.67997733, 0.68996631, 0.69406552, 0.6912856 ,
#        0.71107496, 0.6961387 , 0.6912856 , 0.70886043, 0.75762716,
#        0.74975853, 0.75300958, 0.75461163, 0.76323416, 0.75607227,
#        0.77129123, 0.77670972, 0.78749969, 0.78806507, 0.78820642,
#        0.79371917, 0.79989163, 0.79305952, 0.77411831, 0.78872472,
#        0.78877188, 0.79018535, 0.79489711, 0.79942043, 0.80780735,
#        0.80931515, 0.81647697, 0.80992763, 0.82128298, 0.80351963,
#        0.86962559, 0.89751926, 0.90303201, 0.89478644, 0.91448155,
#        0.90326754, 0.88154633, 0.87122764, 0.87429026, 0.87867223,
#        0.89836735, 0.90237237, 0.8859754 , 0.9148585 , 0.93144391,
#        0.93747495, 0.96004424, 0.96701769, 0.97106974, 0.99133031,
#        0.96583975, 0.97983361, 0.998021  , 1.        , 0.97201215])

# %%
# # Get the models predicted price values
# predictions_scaled = model.predict(np.reshape(x_test[-1].flatten().tolist(), (1, days, 1)))
# predictions = scaler.inverse_transform(predictions_scaled)

# predictions

x_test_last60 = x_test[-1].flatten()
x_test_last60


results = np.array([])

for i in range(0, len(x_test)):

    predictions_scaled = model.predict(np.reshape(x_test_last60, (1, days, 1)))

    x_test_last60 = np.append(x_test_last60[1:], predictions_scaled)

    results = np.append( results, scaler.inverse_transform(predictions_scaled))

results
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# array([223.93507385, 220.46406555, 216.7999115 , 213.40142822,
#        210.4019165 , 207.79782104, 205.52230835, 203.48461914,
#        201.59475708, 199.77763367, 197.97894287, 196.16607666,
#        194.32463074, 192.45372009, 190.56092834, 188.6577301 ,
#        186.75617981, 184.86671448, 182.99710083, 181.15211487,
#        179.33406067, 177.54312134, 175.77824402, 174.03773499,
#        172.31962585, 170.6222229 , 168.94410706, 167.28427124,
#        165.64202881, 164.01715088, 162.40943909, 160.81890869,
#        159.24563599, 157.68960571, 156.15089417, 154.62939453,
#        153.12506104, 151.63775635, 150.16734314, 148.71366882,
#        147.27651978, 145.85577393, 144.45124817, 143.06278992,
#        141.69030762, 140.33361816, 138.99261475, 137.66720581,
#        136.35725403, 135.06266785, 133.78330994, 132.51911926,
#        131.26998901, 130.03578186, 128.81642151, 127.61178589,
#        126.42179871, 125.24633789, 124.08533478, 122.93862915,
#        121.80618286, 120.68786621, 119.58358002, 118.49326324,
#        117.41677856, 116.35404205, 115.30496216, 114.26942444,
#        113.24734497, 112.23863983, 111.24319458, 110.26091003,
#        109.29168701, 108.33544922, 107.39205933, 106.46144104,
#        105.54348755, 104.6381073 , 103.74517822, 102.86462402,
#        101.99633789, 101.14020538, 100.29611969,  99.46400452,
#         98.6437149 ,  97.83518219,  97.0382843 ,  96.2529068 ,
#         95.47897339,  94.71634674,  93.96492767,  93.22463226,
#         92.49531555,  91.77690125,  91.06925201,  90.37228394,
#         89.68587494,  89.00991821,  88.34430695,  87.68893433,
#         87.04368591,  86.40843964,  85.78311157,  85.16757202,
#         84.56171417,  83.96542358,  83.37860107,  82.80113983,
#         82.23291016,  81.67381287,  81.12374878,  80.5825882 ,
#         80.05024719,  79.52658844,  79.01152802,  78.50495148,
#         78.0067215 ,  77.51676941,  77.03498077,  76.56124115,
#         76.09544373,  75.63748932,  75.18725586])

# %%
# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions_scaled - y_test) ** 2)))
rmse
# Out:
# 0.541218585483544

# %%
a = scaler.inverse_transform(y_train.reshape(-1, 1)).flatten().tolist()
b = scaler.inverse_transform(np.reshape(y_test,  (1, len(y_test))))[0].tolist()
pred = results.flatten().tolist()
# pred

# %%
rmse = np.sqrt(np.mean(((predictions - b) ** 2)))
rmse
# Out:
# 59.77662806178198

# %%
new_table = {'Date': data.iloc[60:, :].index.values,
             'Values': a + b,
             'Prediction': a + pred,
             }

df2 = pd.DataFrame(new_table)

# %%
df2["Date"] = pd.to_datetime(df2["Date"])
df3 = df2.set_index('Date').copy(deep=True)
df3
# Out:
#                 Values  Prediction
# Date
# 2014-10-14   24.687500   24.687500
# 2014-10-15   24.385000   24.385000
# 2014-10-16   24.065001   24.065001
# 2014-10-17   24.417500   24.417500
# 2014-10-20   24.940001   24.940001
# ...                ...         ...
# 2024-07-12  230.539993  209.922394
# 2024-07-15  234.399994  209.727158
# 2024-07-16  234.820007  211.188171
# 2024-07-17  228.880005  212.660767
# 2024-07-18  224.179993  211.336884
#
# [2456 rows x 2 columns]

# %%
# Visualize the data
plt.figure(figsize=(16, 6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(df3.tail(200)[['Values', 'Prediction']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
