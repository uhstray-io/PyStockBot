# %%
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import xgboost as xgb
import yfinance as yf

# %%
stock = "AAPL"

# %%
end = datetime.now()
start = datetime(end.year - 20, end.month, end.day)

# %%
df = yf.download(stock, start, end)
df = df.reset_index()
# df

df.columns = [x.lower() for x in df.columns.droplevel(1)]
# df = df.set_index("date")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            date       close        high         low        open     volume
# 0    2005-03-10    1.198628    1.211568    1.176660    1.189600  777109200
# 1    2005-03-11    1.211869    1.221500    1.197726    1.210064  632830800
# 2    2005-03-14    1.213374    1.227518    1.189299    1.219393  605385200
# 3    2005-03-15    1.232634    1.238051    1.211267    1.223004  508608800
# 4    2005-03-16    1.239254    1.273260    1.227217    1.240157  697813200
# ...         ...         ...         ...         ...         ...        ...
# 5027 2025-03-04  235.929993  240.070007  234.679993  237.710007   53798100
# 5028 2025-03-05  235.740005  236.550003  229.229996  235.419998   47227600
# 5029 2025-03-06  235.330002  237.860001  233.160004  234.440002   45170400
# 5030 2025-03-07  239.070007  241.369995  234.759995  235.110001   46245700
# 5031 2025-03-10  227.479996  236.160004  224.220001  235.479996   71374783
#
# [5032 rows x 6 columns]

# %%
# df.stack()

# %%
plt.figure(figsize=(16, 5))
sns.lineplot(x="date", y="close", data=df)
# Out:
# <Axes: xlabel='date', ylabel='close'>

# %%
df
# Out:
#            date       close        high         low        open     volume
# 0    2005-03-10    1.198628    1.211568    1.176660    1.189600  777109200
# 1    2005-03-11    1.211869    1.221500    1.197726    1.210064  632830800
# 2    2005-03-14    1.213374    1.227518    1.189299    1.219393  605385200
# 3    2005-03-15    1.232634    1.238051    1.211267    1.223004  508608800
# 4    2005-03-16    1.239254    1.273260    1.227217    1.240157  697813200
# ...         ...         ...         ...         ...         ...        ...
# 5027 2025-03-04  235.929993  240.070007  234.679993  237.710007   53798100
# 5028 2025-03-05  235.740005  236.550003  229.229996  235.419998   47227600
# 5029 2025-03-06  235.330002  237.860001  233.160004  234.440002   45170400
# 5030 2025-03-07  239.070007  241.369995  234.759995  235.110001   46245700
# 5031 2025-03-10  227.479996  236.160004  224.220001  235.479996   71374783
#
# [5032 rows x 6 columns]

# %%
df.to_parquet("../data/stock_data.parquet")

# %%
# apple= yf.Ticker("aapl")
# apple.actions["Stock Splits"] != 0
# apple.balance_sheet
# apple.dividends
# apple.cashflow
# apple.major_holders
# apple.news
# apple.recommendations
# apple.recommendations_summary
# apple.history(period="1y", interval="1h")
