# %%
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import xgboost as xgb
import yfinance as yf

# %%
stock = "NVDA"

# %%
end = datetime.now()
start = datetime(end.year - 20, end.month, end.day)

# %%
df = yf.download(stock, start, end)
df = df.reset_index()
df.columns = df.columns.str.lower()
# df = df.set_index("date")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.figure(figsize=(16, 5))
sns.lineplot(x="date", y="close", data=df)
# Out:
# <Axes: xlabel='date', ylabel='close'>

# %%
df
# Out:
#            date        open        high         low       close   adj close  \
# 0    2004-09-07    0.107500    0.109750    0.103417    0.104833    0.096156
# 1    2004-09-08    0.104917    0.105833    0.102417    0.102667    0.094169
# 2    2004-09-09    0.105167    0.114750    0.104667    0.112917    0.103571
# 3    2004-09-10    0.111000    0.117833    0.110667    0.117250    0.107545
# 4    2004-09-13    0.117083    0.121833    0.116917    0.119500    0.109609
# ...         ...         ...         ...         ...         ...         ...
# 5028 2024-08-28  128.119995  128.330002  122.639999  125.610001  125.610001
# 5029 2024-08-29  121.360001  124.430000  116.709999  117.589996  117.589996
# 5030 2024-08-30  119.529999  121.750000  117.220001  119.370003  119.370003
# 5031 2024-09-03  116.010002  116.209999  107.290001  108.000000  108.000000
# 5032 2024-09-04  105.379997  113.269997  104.120003  106.209999  106.209999
#
#           volume
# 0      727332000
# 1      834984000
# 2     1299324000
# 3     1039344000
# 4      967752000
# ...          ...
# 5028   448101100
# 5029   453023300
# 5030   333751600
# 5031   474040800
# 5032   367867238
#
# [5033 rows x 7 columns]

# %%
df.to_parquet("../data/stock_data.parquet")

# %%
# apple= yf.Ticker("aapl")
# apple.actions["Stock Splits"] != 0
# apple.balance_sheet
# apple.dividends
# apple.cashflow
# apple.major_holders
# apple.news
# apple.recommendations
# apple.recommendations_summary
# apple.history(period="1y", interval="1h")
