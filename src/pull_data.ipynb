# %%
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import xgboost as xgb
import yfinance as yf

# %%
stock = "AAPL"

# %%
end = datetime.now()
start = datetime(end.year - 20, end.month, end.day)

# %%
df = yf.download(stock, start, end)
df = df.reset_index()
df.columns = df.columns.str.lower()
# df = df.set_index("date")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.figure(figsize=(16, 5))
sns.lineplot(x="date", y="close", data=df)
# Out:
# <Axes: xlabel='date', ylabel='close'>

# %%
df
# Out:
#            date        open        high         low       close   adj close  \
# 0    2004-08-10    0.542679    0.563214    0.541964    0.562857    0.475869
# 1    2004-08-11    0.555357    0.555893    0.540357    0.553750    0.468169
# 2    2004-08-12    0.543750    0.550893    0.540714    0.542321    0.458507
# 3    2004-08-13    0.546429    0.558571    0.542857    0.550714    0.465603
# 4    2004-08-16    0.553571    0.566429    0.547143    0.549643    0.464697
# ...         ...         ...         ...         ...         ...         ...
# 5030 2024-08-05  199.089996  213.500000  196.000000  209.270004  209.270004
# 5031 2024-08-06  205.300003  209.990005  201.070007  207.229996  207.229996
# 5032 2024-08-07  206.899994  213.639999  206.389999  209.820007  209.820007
# 5033 2024-08-08  213.110001  214.199997  208.830002  213.309998  213.309998
# 5034 2024-08-09  212.100006  216.779999  211.970001  216.240005  216.240005
#
#          volume
# 0     351036000
# 1     322392000
# 2     226200800
# 3     328048000
# 4     435674400
# ...         ...
# 5030  119548600
# 5031   69660500
# 5032   63516400
# 5033   47161100
# 5034   42171700
#
# [5035 rows x 7 columns]

# %%
df.to_parquet("../data/stock_data.parquet")

# %%
# apple= yf.Ticker("aapl")
# apple.actions["Stock Splits"] != 0
# apple.balance_sheet
# apple.dividends
# apple.cashflow
# apple.major_holders
# apple.news
# apple.recommendations
# apple.recommendations_summary
# apple.history(period="1y", interval="1h")
